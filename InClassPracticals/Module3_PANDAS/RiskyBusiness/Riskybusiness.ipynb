# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %matplotlib inline  

# Set the path of the CSV files
harold_path = Path("harold_portfolio.csv")
harold_csv = pd.read_csv(harold_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
harold_csv.dropna()

my_path = Path("my_portfolio.csv")
#axis=1 columns
me_csv = pd.read_csv(my_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
me_csv.dropna()

#Calculate daily returns
 # Calculate daily returns for each portfolio
harold_csv.pct_change()
me_csv.pct_change()

both_csv = pd.concat([harold_csv, me_csv], axis=1)
both_csv.head()

both_csv_std = both_csv.std()
both_csv.head()


  Calculate sharpe ratio for all data
 # Calculate sharpe ratio
  Plot Sharpe Ratios
 # Plot sharpe ratios using a bar chart
  How many smart investments did Harold make compared to risky investments? How many did you make?
 Your answer here Which three cryptos were the smartest investments?
 Your answer here Challenge
Calculate the Sharpe ratio for your entire portfolio. Then, use a comparison operator to see which portfolio has the greatest risk-to-reward ratio. Calculate annualized standard deviaton for each portfolio individually
 # Calculate standard deviaton for all investments for each portfolio
  # Print Harold's annual standard deviation 252 gives annual return
  # Print my annual standard deviation
  Calculate the sharpe ratios for each individual portfolio
 # Calculate sharpe ratios
  # Print Harold's sharpe ratios
  # Print my sharpe ratios
  Average sharpe ratios for each portfolio and output to screen
 # Averaging sharpe ratios
)

# Display results
print("Harold's sharpe ratio average:", harold_sharpe_avg)
print("My sharpe ratio average:", my_sharpe_avg)  Compare Sharpe Ratios Averages
 # Determine if Harold's average is greater
# HINT: Use a comparison operator like so: harold_sharpe_avg > my_sharpe_avg
  Which portfolio is the smartest investment, based on risk to reward ratio?
Your answer here
# Out:
#                 BTC       BTT      DOGE     ETH     LTC       XRP     SOLVE  \
# Date
# 2019-05-20  8118.39  0.001187  0.003041  261.09   95.06  0.398003  0.338667
# 2019-05-19  8200.00  0.001056  0.003178  234.03   86.65  0.417700  0.300430
# 2019-05-18  7262.40  0.000993  0.003005  244.59   89.88  0.372736  0.287630
# 2019-05-17  7363.69  0.000957  0.002962  264.39   95.75  0.386193  0.259506
# 2019-05-16  7878.96  0.000885  0.003168  249.00  102.26  0.419707  0.223316
#
#                  XLM      TRON       ZIL      BTC      DOGE     ETH     LTC  \
# Date
# 2019-05-20  0.135545  0.028509  0.017992  8200.00  0.003041  261.09   95.06
# 2019-05-19  0.141485  0.029277  0.019170  7262.40  0.003178  234.03   86.65
# 2019-05-18  0.128833  0.026823  0.017685  7363.69  0.003005  244.59   89.88
# 2019-05-17  0.126562  0.027220  0.017892  7878.96  0.002962  264.39   95.75
# 2019-05-16  0.137283  0.028857  0.018725  8203.32  0.003168  249.00  102.26
#
#                  XRP       XLM
# Date
# ...
